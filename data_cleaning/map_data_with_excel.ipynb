# %%
import pandas as pd
import numpy as np

# Seed for reproducibility
np.random.seed(0)

# Parameters
num_records = 1000
age_min, age_max = 1, 100
num_symptoms = 5
symptoms = ["Fever", "Cough", "Fatigue", "Shortness of Breath", "Loss of Taste or Smell"]
diseases = ["None", "Flu", "COVID-19", "Cold", "Allergy"]
vaccination_status = ["Not Vaccinated", "Partially Vaccinated", "Fully Vaccinated"]

# Generating Data
data = {
    "Person_ID": np.arange(1, num_records + 1),
    "Age": np.random.randint(age_min, age_max + 1, size=num_records),
    "Gender": np.random.choice(["Male", "Female", "Other"], size=num_records),
    "Disease": np.random.choice(diseases, size=num_records),
    "Vaccination_Status": np.random.choice(vaccination_status, size=num_records)
}

# Adding symptoms as binary features (1 for present, 0 for absent)
for symptom in symptoms:
    data[symptom] = np.random.randint(0, 2, size=num_records)

# Creating DataFrame
df = pd.DataFrame(data)
df.to_csv("original_data.csv", index=False)
# Out:
#      Person_ID  Age  Gender   Disease    Vaccination_Status  Fever  Cough  \
# 0            1   45    Male      None        Not Vaccinated      0      0
# 1            2   48   Other   Allergy  Partially Vaccinated      0      1
# 2            3   65  Female  COVID-19      Fully Vaccinated      1      0
# 3            4   68   Other      None        Not Vaccinated      0      0
# 4            5   68   Other       Flu  Partially Vaccinated      0      0
# ..         ...  ...     ...       ...                   ...    ...    ...
# 195        196   84    Male      Cold        Not Vaccinated      0      1
# 196        197   34   Other      None      Fully Vaccinated      1      1
# 197        198   33    Male  COVID-19  Partially Vaccinated      1      0
# 198        199   71   Other  COVID-19        Not Vaccinated      1      1
# 199        200   86   Other       Flu      Fully Vaccinated      1      0
#
#      Fatigue  Shortness of Breath  Loss of Taste or Smell
# 0          1                    1                       0
# 1          0                    1                       1
# 2          0                    1                       0
# 3          1                    0                       1
# 4          0                    1                       0
# ..       ...                  ...                     ...
# 195        1                    1                       1
# 196        0                    1                       1
# 197        1                    0                       1
# 198        1                    0                       1
# 199        1                    1                       0
#
# [200 rows x 10 columns]

# %%
df
# Out:
#      Person_ID  Age  Gender   Disease    Vaccination_Status  Fever  Cough  \
# 0            1   45    Male      None        Not Vaccinated      0      0
# 1            2   48   Other   Allergy  Partially Vaccinated      0      1
# 2            3   65  Female  COVID-19      Fully Vaccinated      1      0
# 3            4   68   Other      None        Not Vaccinated      0      0
# 4            5   68   Other       Flu  Partially Vaccinated      0      0
# ..         ...  ...     ...       ...                   ...    ...    ...
# 995        996   27    Male      None        Not Vaccinated      0      1
# 996        997   49  Female      Cold        Not Vaccinated      0      1
# 997        998   72  Female   Allergy      Fully Vaccinated      0      1
# 998        999   55   Other      Cold        Not Vaccinated      1      0
# 999       1000   97  Female  COVID-19        Not Vaccinated      0      1
#
#      Fatigue  Shortness of Breath  Loss of Taste or Smell
# 0          1                    1                       0
# 1          0                    1                       1
# 2          0                    1                       0
# 3          1                    0                       1
# 4          0                    1                       0
# ..       ...                  ...                     ...
# 995        1                    1                       0
# 996        1                    0                       1
# 997        1                    0                       0
# 998        0                    0                       1
# 999        1                    1                       1
#
# [1000 rows x 10 columns]

# %%
import pandas as pd

# Load the mapping rules from the Excel file
mapping_df = pd.read_excel('mapping.xlsx')

# Preparing the mapping structure
# Fill NaN in 'Field' to make it easier to fill down and identify mappings that span multiple rows
mapping_df['Field'] = mapping_df['Field'].fillna(method='ffill')
# For New Field Name, where NaN appears, it should inherit the original Field name (indicating no change)
mapping_df['New Field'] = mapping_df['New Field'].fillna(method='ffill')

mapping_df
# Out:
#                      Field                                        Description  \
# 0                Person_ID                 Unique identifier for each person.
# 1                      Age                                 Age of the person.
# 2                   Gender                     Gender identity of the person.
# 3                   Gender                                                NaN
# 4                   Gender                                                NaN
# 5                  Disease                   Diagnosed disease of the person.
# 6                  Disease                                                NaN
# 7                  Disease                                                NaN
# 8                  Disease                                                NaN
# 9                  Disease                                                NaN
# 10      Vaccination_Status  Vaccination status against COVID-19 of the per...
# 11      Vaccination_Status                                                NaN
# 12      Vaccination_Status                                                NaN
# 13                   Fever                         Presence of fever symptom.
# 14                   Fever                                                NaN
# 15                   Cough                         Presence of cough symptom.
# 16                   Cough                                                NaN
# 17                 Fatigue                       Presence of fatigue symptom.
# 18                 Fatigue                                                NaN
# 19     Shortness of Breath           Presence of shortness of breath symptom.
# 20     Shortness of Breath                                                NaN
# 21  Loss of Taste or Smell        Presence of loss of taste or smell symptom.
# 22  Loss of Taste or Smell                                                NaN
#
#                Type          Range/Values        New Field  New Range/Values
# 0           Integer             1 to 1000               id               NaN
# 1           Integer        1 to 100 years     age_in_years               NaN
# 2       Categorical                  Male              sex                 M
# 3               NaN                Female              sex                 F
# 4               NaN                 Other              sex                 O
# 5       Categorical                   NaN  type_of_disease              Well
# 6               NaN                   Flu  type_of_disease       Respiratory
# 7               NaN              COVID-19  type_of_disease       Respiratory
# 8               NaN                  Cold  type_of_disease       Respiratory
# 9               NaN               Allergy  type_of_disease           Allergy
# 10      Categorical        Not Vaccinated       vax_status    Not Vaccinated
# 11              NaN  Partially Vaccinated       vax_status    Not Vaccinated
# 12              NaN      Fully Vaccinated       vax_status  Fully Vaccinated
# 13  Binary (0 or 1)                     0            fever            Absent
# 14              NaN                     1            fever           Present
# 15  Binary (0 or 1)                     0            cough            Absent
# 16              NaN                     1            cough           Present
# 17  Binary (0 or 1)                     0          fatigue            Absent
# 18              NaN                     1          fatigue           Present
# 19  Binary (0 or 1)                     0            s_o_b            Absent
# 20              NaN                     1            s_o_b           Present
# 21  Binary (0 or 1)                     0            l_t_s            Absent
# 22              NaN                     1            l_t_s           Present

# %%
import pandas as pd

def apply_data_mapping(original_data_path, mapping_path):
    """
    Applies mapping rules defined in an Excel file to a dataset contained in a CSV file.

    Parameters:
    - original_data_path: The file path to the CSV file containing the original data.
    - mapping_path: The file path to the Excel file containing the mapping rules.

    Returns:
    - rearranged_df: A DataFrame with the original and transformed columns, as per the mapping rules.
    """
    
    # Load the mapping rules from the Excel file
    mapping_df = pd.read_excel(mapping_path)

    # Fill NaN in 'Field' to identify mappings that span multiple rows
    mapping_df['Field'] = mapping_df['Field'].fillna(method='ffill')
    # For New Field Name, where NaN appears, it should inherit the first New Field name
    mapping_df['New Field'] =  mapping_df['New Field'].fillna(method='ffill')

    # Prepare the structure for value mappings
    value_mappings = {}
    for index, row in mapping_df.iterrows():
        field, new_field = row['Field'], row['New Field']
        original_value, new_value = row['Range/Values'], row['New Range/Values']
        if new_field not in value_mappings:
            value_mappings[new_field] = {'original_field': field, 'value_mapping': {}}
        if pd.notna(original_value) and pd.notna(new_value):
            value_mappings[new_field]['value_mapping'][original_value] = new_value

    # Load the original data
    original_data_df = pd.read_csv(original_data_path, keep_default_na=False)

    # Apply the mappings
    transformed_data_df = original_data_df.copy()
    for new_field, mapping in value_mappings.items():
        original_field = mapping['original_field']
        if original_field in transformed_data_df.columns:
            if mapping['value_mapping']:
                transformed_data_df[new_field] = transformed_data_df[original_field].map(mapping['value_mapping']).fillna(transformed_data_df[original_field])
            elif original_field != new_field:
                transformed_data_df[new_field] = transformed_data_df[original_field]

    # Rearrange columns to show original fields next to their new fields
    column_order = []
    for new_field, mapping in value_mappings.items():
        original_field = mapping['original_field']
        if original_field in transformed_data_df.columns and original_field != new_field:
            column_order.extend([original_field, new_field])
    for col in original_data_df.columns:
        if col not in column_order:
            column_order.append(col)

    rearranged_df = transformed_data_df[column_order]
    return rearranged_df
rearranged_df = apply_data_mapping('original_data.csv', 'mapping.xlsx')

# %%
rearranged_df.to_excel("mapped_data.xlsx") 
rearranged_df
# Out:
#      Person_ID    id  Age  age_in_years  Gender sex   Disease type_of_disease  \
# 0            1     1   45            45    Male   M      None            None
# 1            2     2   48            48   Other   O   Allergy         Allergy
# 2            3     3   65            65  Female   F  COVID-19     Respiratory
# 3            4     4   68            68   Other   O      None            None
# 4            5     5   68            68   Other   O       Flu     Respiratory
# ..         ...   ...  ...           ...     ...  ..       ...             ...
# 995        996   996   27            27    Male   M      None            None
# 996        997   997   49            49  Female   F      Cold     Respiratory
# 997        998   998   72            72  Female   F   Allergy         Allergy
# 998        999   999   55            55   Other   O      Cold     Respiratory
# 999       1000  1000   97            97  Female   F  COVID-19     Respiratory
#
#        Vaccination_Status        vax_status  Fever    fever  Cough    cough  \
# 0          Not Vaccinated    Not Vaccinated      0   Absent      0   Absent
# 1    Partially Vaccinated    Not Vaccinated      0   Absent      1  Present
# 2        Fully Vaccinated  Fully Vaccinated      1  Present      0   Absent
# 3          Not Vaccinated    Not Vaccinated      0   Absent      0   Absent
# 4    Partially Vaccinated    Not Vaccinated      0   Absent      0   Absent
# ..                    ...               ...    ...      ...    ...      ...
# 995        Not Vaccinated    Not Vaccinated      0   Absent      1  Present
# 996        Not Vaccinated    Not Vaccinated      0   Absent      1  Present
# 997      Fully Vaccinated  Fully Vaccinated      0   Absent      1  Present
# 998        Not Vaccinated    Not Vaccinated      1  Present      0   Absent
# 999        Not Vaccinated    Not Vaccinated      0   Absent      1  Present
#
#      Fatigue  fatigue  Shortness of Breath    s_o_b  Loss of Taste or Smell  \
# 0          1  Present                    1  Present                       0
# 1          0   Absent                    1  Present                       1
# 2          0   Absent                    1  Present                       0
# 3          1  Present                    0   Absent                       1
# 4          0   Absent                    1  Present                       0
# ..       ...      ...                  ...      ...                     ...
# 995        1  Present                    1  Present                       0
# 996        1  Present                    0   Absent                       1
# 997        1  Present                    0   Absent                       0
# 998        0   Absent                    0   Absent                       1
# 999        1  Present                    1  Present                       1
#
#        l_t_s
# 0     Absent
# 1    Present
# 2     Absent
# 3    Present
# 4     Absent
# ..       ...
# 995   Absent
# 996  Present
# 997   Absent
# 998  Present
# 999  Present
#
# [1000 rows x 20 columns]
